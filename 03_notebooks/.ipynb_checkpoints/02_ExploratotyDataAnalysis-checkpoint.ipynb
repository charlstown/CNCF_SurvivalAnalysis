# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# **Description:** this notebook executes and explains the loading data process for the assignment. The goal for this notebook is to load and create the index with our personal mapping document.
#
# **Data:** the data loaded was from the Cloud Native Computing Foundation database.
#
# **Team members:** Verónica Gómez, Carlos Grande y Pablo Olmos
#
# **GitHub URL:** https://github.com/charlstown/CNCF_SurvivalAnalysis.git

# %% [markdown]
# ## INDEX:
# * [1 The data](#data)
# * [Second Bullet Header](#second-bullet)
# ---

# %% [markdown]
# ## Libraries needed

# %%
from datetime import datetime
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search
from elasticsearch_dsl import Q
import json
from matplotlib import pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Connecting to elastic

# %%
elastic = Elasticsearch(["http://127.0.0.1:9200"])
idx =  'cncf_mapped'
print(elastic)
# Out:
# <Elasticsearch([{'host': '127.0.0.1', 'port': 9200}])>

# %%
indexes = elastic.indices.get_alias("*").keys()
[print(i) for i in indexes];
# Out:
# cncf_dataset
# company
# .async-search
# .kibana_1
# .apm-agent-configuration
# .apm-custom-link
# cncf_mapped
# .kibana_task_manager_1

# %% [markdown]
# ## Importing scripts
# In this section we import the attributes from our python library **elastic_loader** saved on folder "src".

# %%
import sys
sys.path.append('../02_src/')
import elastic_loader as el

# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Explaining data <a class="anchor" id="data">

# %%
ids = ['91d824e7ddb3a16bbe0e229fa62cc88a7415c3e2', \
       '3a64071cf70ac4c49760a34907ffde303cd6f867', \
       'e18491976256aef320e1adef030bf52f25b97367']


df = pd.DataFrame.from_dict([elastic.get(idx, i)['_source'] for i in ids])
df
# Out:
#   Author_gender       demography_min_date metadata__gelk_backend_name  tz  \
# 0       Unknown  2018-12-28T11:53:52.000Z                   GitEnrich  -2
# 1       Unknown  2017-08-14T08:13:15.000Z                   GitEnrich   8
# 2       Unknown  2018-09-29T17:50:34.000Z                   GitEnrich  -4
#
#      project               metadata__timestamp  \
# 0  Graduated  2019-08-02T14:22:43.155789+00:00
# 1  Graduated  2019-08-02T13:50:48.170987+00:00
# 2  Graduated  2019-08-02T14:12:22.173595+00:00
#
#                                        uuid Author_user_name   cm_title  \
# 0  91d824e7ddb3a16bbe0e229fa62cc88a7415c3e2          Unknown  Graduated
# 1  3a64071cf70ac4c49760a34907ffde303cd6f867          Unknown  Graduated
# 2  e18491976256aef320e1adef030bf52f25b97367          Unknown  Graduated
#
#                                   Commit_id Commit_user_name  \
# 0  183f4592bb7b37d6053a6a9ce9980c599c766ba2          Unknown
# 1  89f70c744bcf132b71b68d11a2fecdd2b7c93cb4          Unknown
# 2  26d5d38867d0acce085b6b8daefd17322e820891          Unknown
#
#               metadata__enriched_on          author_date  Author_domain  \
# 0  2019-10-07T19:41:38.181669+00:00  2018-12-28T09:53:52  loadsmart.com
# 1  2019-10-07T18:37:00.312067+00:00  2017-08-29T03:20:29     huawei.com
# 2  2019-10-07T19:36:15.023664+00:00  2019-04-05T11:46:04     google.com
#
#                                             tag  author_bot  \
# 0    https://github.com/kubernetes/minikube.git       False
# 1     https://github.com/kubernetes/website.git       False
# 2  https://github.com/kubernetes/kubernetes.git       False
#
#                                     message_analyzed author_org_name  \
# 0  Adding ReportError test and HTTP Test server r...         Unknown
# 1  Update images.md (#5212)\n\n* Update images.md...         Unknown
# 2  github.com/mitchellh/mapstructure v1.1.2\n\nUs...         Unknown
#
#   hash_short repository_labels          commit_date Author_org_name  \
# 0     f948bf                []  2018-12-28T10:04:45         Unknown
# 1     127225                []  2017-08-28T12:20:29         Unknown
# 2     319ff2                []  2019-04-08T15:20:44         Unknown
#
#    project_1                               Author_uuid offset  lines_added  \
# 0  Graduated  183f4592bb7b37d6053a6a9ce9980c599c766ba2   None           21
# 1  Graduated  c04049bcd92d96bcfb399a80c9197c63dbc82728   None           15
# 2  Graduated  26d5d38867d0acce085b6b8daefd17322e820891   None          530
#
#    utc_commit_date_weekday          committer_domain  author_date_hour  \
# 0                        5             loadsmart.com                 9
# 1                        1  users.noreply.github.com                 3
# 2                        1                google.com                11
#
#    commit_date_weekday                               Commit_uuid branches  \
# 0                    5  183f4592bb7b37d6053a6a9ce9980c599c766ba2       []
# 1                    1  89f70c744bcf132b71b68d11a2fecdd2b7c93cb4       []
# 2                    1  26d5d38867d0acce085b6b8daefd17322e820891       []
#
#    committer_name Commit_gender  Author_gender_acc  author_date_weekday  \
# 0    Amim Knabben       Unknown                  0                    5
# 1     Andrew Chen       Unknown                  0                    2
# 2  Jordan Liggitt       Unknown                  0                    5
#
#   Commit_org_name  files metadata__gelk_version  \
# 0         Unknown      1                 0.62.0
# 1         Unknown      1                 0.62.0
# 2         Unknown     11                 0.62.0
#
#                                   author_id  \
# 0  183f4592bb7b37d6053a6a9ce9980c599c766ba2
# 1  c04049bcd92d96bcfb399a80c9197c63dbc82728
# 2  26d5d38867d0acce085b6b8daefd17322e820891
#
#                                        hash     author_name author_gender  \
# 0  f948bf81368eb13afc7270e4ad9fd9a4126c6ff2    Amim Knabben       Unknown
# 1  12722567fe7ef27611762e5bd611068735f7b68d      stewart-yu       Unknown
# 2  319ff2fd3146966af5830e114db61ed356f28fe0  Jordan Liggitt       Unknown
#
#             utc_author git_author_domain  is_git_commit  \
# 0  2018-12-28T11:53:52     loadsmart.com              1
# 1  2017-08-28T19:20:29        huawei.com              1
# 2  2019-04-05T15:46:04        google.com              1
#
#                                          origin  utc_author_date_weekday  \
# 0    https://github.com/kubernetes/minikube.git                        5
# 1     https://github.com/kubernetes/website.git                        1
# 2  https://github.com/kubernetes/kubernetes.git                        5
#
#                                   Author_id  \
# 0  183f4592bb7b37d6053a6a9ce9980c599c766ba2
# 1  c04049bcd92d96bcfb399a80c9197c63dbc82728
# 2  26d5d38867d0acce085b6b8daefd17322e820891
#
#                                               url_id  \
# 0  kubernetes/minikube/commit/f948bf81368eb13afc7...
# 1  kubernetes/website/commit/12722567fe7ef2761176...
# 2  kubernetes/kubernetes/commit/319ff2fd3146966af...
#
#                                                title            github_repo  \
# 0  Adding ReportError test and HTTP Test server r...    kubernetes/minikube
# 1                           Update images.md (#5212)     kubernetes/website
# 2           github.com/mitchellh/mapstructure v1.1.2  kubernetes/kubernetes
#
#    lines_changed  utc_commit_date_hour       demography_max_date  \
# 0             28                    12  2018-12-28T12:44:34.000Z
# 1             30                    19  2019-05-22T07:45:51.000Z
# 2            648                    19  2020-05-14T21:22:07.000Z
#
#   author_user_name     grimoire_creation_date  Commit_bot  author_gender_acc  \
# 0          Unknown  2018-12-28T09:53:52-02:00       False                  0
# 1          Unknown  2017-08-29T03:20:29+08:00       False                  0
# 2          Unknown  2019-04-05T11:46:04-04:00       False                  0
#
#    Commit_gender_acc             Commit_domain  author_domain  \
# 0                  0             loadsmart.com  loadsmart.com
# 1                  0  users.noreply.github.com     huawei.com
# 2                  0                google.com     google.com
#
#                                       repo_name  \
# 0    https://github.com/kubernetes/minikube.git
# 1     https://github.com/kubernetes/website.git
# 2  https://github.com/kubernetes/kubernetes.git
#
#                                    git_uuid  lines_removed  \
# 0  91d824e7ddb3a16bbe0e229fa62cc88a7415c3e2              7
# 1  3a64071cf70ac4c49760a34907ffde303cd6f867             15
# 2  e18491976256aef320e1adef030bf52f25b97367            118
#
#             utc_commit  commit_date_hour metadata__filter_raw  Author_bot  \
# 0  2018-12-28T12:04:45                10                 None       False
# 1  2017-08-28T19:20:29                12                 None       False
# 2  2019-04-08T19:20:44                15                 None       False
#
#                                              message  \
# 0  Adding ReportError test and HTTP Test server r...
# 1  Update images.md (#5212)\n\n* Update images.md...
# 2  github.com/mitchellh/mapstructure v1.1.2\n\nUs...
#
#                                 author_uuid  time_to_commit_hours  \
# 0  183f4592bb7b37d6053a6a9ce9980c599c766ba2                 23.82
# 1  c04049bcd92d96bcfb399a80c9197c63dbc82728                  0.00
# 2  26d5d38867d0acce085b6b8daefd17322e820891                 20.42
#
#    utc_author_date_hour     Commit_name     Author_name  \
# 0                    11    Amim Knabben    Amim Knabben
# 1                    19     Andrew Chen      stewart-yu
# 2                    15  Jordan Liggitt  Jordan Liggitt
#
#         metadata__updated_on
# 0  2018-12-28T12:04:45+00:00
# 1  2017-08-28T19:20:29+00:00
# 2  2019-04-08T19:20:44+00:00

# %%
[print(col) for col in df.columns];
# Out:
# Author_gender
# demography_min_date
# metadata__gelk_backend_name
# tz
# project
# metadata__timestamp
# uuid
# Author_user_name
# cm_title
# Commit_id
# Commit_user_name
# metadata__enriched_on
# author_date
# Author_domain
# tag
# author_bot
# message_analyzed
# author_org_name
# hash_short
# repository_labels
# commit_date
# Author_org_name
# project_1
# Author_uuid
# offset
# lines_added
# utc_commit_date_weekday
# committer_domain
# author_date_hour
# commit_date_weekday
# Commit_uuid
# branches
# committer_name
# Commit_gender
# Author_gender_acc
# author_date_weekday
# Commit_org_name
# files
# metadata__gelk_version
# author_id
# hash
# author_name
# author_gender
# utc_author
# git_author_domain
# is_git_commit
# origin
# utc_author_date_weekday
# Author_id
# url_id
# title
# github_repo
# lines_changed
# utc_commit_date_hour
# demography_max_date
# author_user_name
# grimoire_creation_date
# Commit_bot
# author_gender_acc
# Commit_gender_acc
# Commit_domain
# author_domain
# repo_name
# git_uuid
# lines_removed
# utc_commit
# commit_date_hour
# metadata__filter_raw
# Author_bot
# message
# author_uuid
# time_to_commit_hours
# utc_author_date_hour
# Commit_name
# Author_name
# metadata__updated_on

# %% [markdown]
# ## 2. Running queries

# %% [markdown]
# ### 2.1 About developers

# %% [markdown]
# #### A. How many unique developers are in the CNCF project

# %%
s = Search(using=elastic, index=idx)
s.aggs.metric('Number of developers', 'cardinality', field='Author_id')

result = s.execute()
result.to_dict()["aggregations"]
# Out:
# {'Number of developers': {'value': 16691}}

# %% [markdown]
# #### B. How many developers are involved filtered by year

# %%
year = 2020    # please type the year to call the query

s = Search(using=elastic, index=idx).filter('range', author_date={'gt': datetime(year-1, 12, 12), 'lt': datetime(year, 1, 1)})
s.aggs.metric('developers', 'cardinality', field='hash')
result = s.execute()
result.to_dict()["aggregations"]
# Out:
# {'developers': {'value': 3930}}

# %%
years = range(2010, 2021)

output = []
for year in years:
    s = Search(using=elastic, index=idx).filter('range', author_date={'gt': datetime(year-1, 12, 12), 'lt': datetime(year, 1, 1)})
    s.aggs.metric('developers', 'cardinality', field='hash')
    result = s.execute()
    result = result.to_dict()["aggregations"]['developers']['value']
    output.append(result)

# %%
plt.figure(figsize=(15,6))
plt.bar(years, output)
plt.xticks(years, years)
plt.title('Developers involved by year')
plt.show()

# %% [markdown]
# #### C. Main developers

# %% [markdown]
# #### D.
